# %%
# !python --version
# Out:
# Python 3.12.11

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Ch01/win.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=580x856>

# %%
RGB_img = cv2.cvtColor(img. cv2.COLOR_BG2BGR)
plt.imshow(RGB_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3824799167.py in <cell line: 0>()
# ----> 1 RGB_img = cv2.cvtColor(img. cv2.COLOR_BG2BGR)
#       2 plt.imshow(RGB_img)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cv2'
